# %% [markdown]
# ### Start the initial run from here!

# %%
# %cd /kaggle/working
# !git clone https://github.com/hoangtrung020541/personalized_styler.git
# %cd /kaggle/working/personalized_styler/oh_my_posh_linux
# !bash oh_my_posh.sh
# %cd /kaggle/working

# %%
# SSH public key
public_key_path = 'https://codinghfi.obs.cn-south-1.myhuaweicloud.com/%E5%BA%A7%E4%BD%8D/authorized_keys'

# password = ''.join(random.choice(string.ascii_letters + string.digits) for i in range(20))
password = 'kaggle'

# Setup sshd
! apt-get install -qq -o=Dpkg::Use-Pty=0 openssh-server pwgen > /dev/null

# Setup authenticational
! echo root:$password | chpasswd
! mkdir /kaggle/working/.ssh
! wget -P /kaggle/working/.ssh $public_key_path
! chmod 700 /kaggle/working/.ssh
! chmod 600 /kaggle/working/.ssh/authorized_keys

# %%
# !sudo apt-get update --allow-releaseinfo-change

# %%
# Only run for the first time when creating this notebook
# %cd /kaggle/working
# !git clone https://github.com/hoangtrung020541/remote-ssh-kaggle-vscode.git

# %% [markdown]
# ### Rerun starts here!

# %%
# Config sshd server
! mkdir -p /var/run/sshd
! echo "Protocol 2" >> /etc/ssh/sshd_config
! echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
! echo "PasswordAuthentication no" >> /etc/ssh/sshd_config
! echo "TCPKeepAlive yes" >> /etc/ssh/sshd_config
! echo "X11Forwarding yes" >> /etc/ssh/sshd_config
! echo "X11DisplayOffset 10" >> /etc/ssh/sshd_config
! echo "AuthorizedKeysFile /kaggle/working/.ssh/authorized_keys" >> /etc/ssh/sshd_config
! echo "PubkeyAuthentication yes" >> /etc/ssh/sshd_config
! echo "IgnoreRhosts yes" >> /etc/ssh/sshd_config
! echo "HostbasedAuthentication no" >> /etc/ssh/sshd_config
! echo "PrintLastLog yes" >> /etc/ssh/sshd_config
! echo "AcceptEnv LANG LC_*" >> /etc/ssh/sshd_config

! echo "LD_LIBRARY_PATH=/opt/conda/lib" >> /root/.bashrc
! echo "export LD_LIBRARY_PATH" >> /root/.bashrc

! ln -s /opt/conda/bin/* /bin/ > /dev/null 2>&1

# %cd /kaggle/working/personalized_styler/oh_my_posh_linux
! bash oh_my_posh.sh
# %cd /kaggle/working
! chmod a+x /kaggle/working/.vscode/install_tools.sh
print("Done!")
# Out:
# /kaggle/working/personalized_styler/oh_my_posh_linux
#
# ℹ️  Installing oh-my-posh for linux-amd64 in /usr/local/bin
# ⬇️  Downloading oh-my-posh from https://github.com/JanDeDobbeleer/oh-my-posh/releases/latest/download/posh-linux-amd64
# 🎨 Installing oh-my-posh themes in /root/.cache/oh-my-posh/themes
#
# 🚀 Installation complete.
#
# You can follow the instructions at https://ohmyposh.dev/docs/installation/prompt
# to setup your shell to use oh-my-posh.
#
# If you want to use a built-in theme, you can find them in the  directory:
#   oh-my-posh init {shell} --config /{theme}.omp.json
#
# /kaggle/working
# Done!

# %%
# Required: After running this tile, stop and run again

# %cd /kaggle/working/remote-ssh-kaggle-vscode
# !bash install_ssh_server.sh public_key_path

# Copy authtoken from https://dashboard.ngrok.com/auth
# !bash add_ngrok_token.sh 2dA5LkAJAbAdD8LI5koDM1k8B0c_4wuDKfjZqsSSDhAkqVEuA
# Out:
# /kaggle/working/remote-ssh-kaggle-vscode
# public_key_path
# --2024-06-05 05:31:11--  http://public_key_path/
# Resolving public_key_path (public_key_path)... failed: Name or service not known.
# wget: unable to resolve host address 'public_key_path'
# --2024-06-05 05:31:11--  https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# Resolving bin.equinox.io (bin.equinox.io)... 18.205.222.128, 52.202.168.65, 54.237.133.81, ...
# Connecting to bin.equinox.io (bin.equinox.io)|18.205.222.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8965855 (8.5M) [application/octet-stream]
# Saving to: 'ngrok-v3-stable-linux-amd64.tgz'
#
# ngrok-v3-stable-lin 100%[===================>]   8.55M  11.0MB/s    in 0.8s
#
# 2024-06-05 05:31:12 (11.0 MB/s) - 'ngrok-v3-stable-linux-amd64.tgz' saved [8965855/8965855]
#
# ngrok
# Hit:1 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:2 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:4 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:6 https://packages.cloud.google.com/apt google-fast-socket InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 75 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# openssh-server is already the newest version (1:8.2p1-4ubuntu0.11).
# 0 upgraded, 0 newly installed, 0 to remove and 75 not upgraded.
#  * Restarting OpenBSD Secure Shell server sshd
#    ...done.
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !bash run_ssh_server.sh
# Out:
# Flag --region has been deprecated, ngrok automatically chooses the region with lowest latency
# 7=ngrok                                                           (Ctrl+C to quit)                                                                                Session Status                connecting                                        Version                       3.10.0                                            Web Interface                 http://127.0.0.1:4040                                                                                                             Connections                   ttl     opn     rt1     rt5     p50     p90                                     0       0       0.00    0.00    0.00    0.00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      K8s Gateway API support available now: https://ngrok.com/r/k8sgb                                    Session Status                online               Account                       Amazingkenneth (Plan: Free)Version    3.10.0                                          RegionAsiaPacific(ap)                               Web Interface                 http://127.0.0.1:4040Forwarding                    tcp://0.tcp.ap.ngrok.io:13091 -> localhost:22Connections                   ttl     opn     rt1     rt5     p50     p90                                   0       0       0.00    0.00    0.00    0.00    1Latency      199ms                Web Interfacehttp:/127.0.01:4040                        Forwarding                    tcp://0.tcp.ap.ngrok.io:13091 -> localhost:22                                                                              Connectionsttlopnrt1 rt5 p5 p9                               0       1       0.00    0.00    0.00    0.00    1055.355.31220011990200199
